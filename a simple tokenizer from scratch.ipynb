# %%
import urllib.request
url=("https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/main/ch02/01_main-chapter-code/the-verdict.txt")
file_path='the-verdict.txt'
urllib.request.urlretrieve(url,file_path)
# Out:
# ('the-verdict.txt', <http.client.HTTPMessage at 0x2419ddafed0>)

# %%
##written character upto a limit meaning letter and all not entire word from the file
with open("the-verdict.txt",'r',encoding='utf-8') as f:
 raw_text=f.read()
print("total character in the given story or the link",len(raw_text))
print(raw_text[:99])
# Out:
# total character in the given story or the link 20479
# I HAD always thought Jack Gisburn rather a cheap genius--though a good fellow enough--so it was no

# %%
##importing re for tokenizing just for fun 

import re
text='hello world .this, is a test.'
result=re.split(r'(\s)',text) ## if u find a pattern like white space spilit from there
print(result)
# Out:
# ['hello', ' ', 'world', ' ', '.this,', ' ', 'is', ' ', 'a', ' ', 'test.']

# %%
import re
text='hello world .this, is a test.'
result=re.split(r'([,.]|\s)',text) ## if u find a pattern like white space spilit from there
print(result)
# Out:
# ['hello', ' ', 'world', ' ', '', '.', 'this', ',', '', ' ', 'is', ' ', 'a', ' ', 'test', '.', '']

# %%
##white space free output
import re
text='hello world .this, is a test.'
result=re.split(r'([,.]|\s)',text) ## if u find a pattern like white space spilit from there
result=[removespace for removespace in result if removespace.split()] ##returing all those does not spaces in bwtween either
print(result)
# Out:
# ['hello', 'world', '.', 'this', ',', 'is', 'a', 'test', '.']
